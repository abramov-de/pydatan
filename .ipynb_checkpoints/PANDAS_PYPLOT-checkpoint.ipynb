# %% [markdown]
# # Pandas + Pyplot
#
# ## Theory
#
# Pandas is a data analysis and manipulation package for tabular data, such as data stored in spreadsheets or databases. It is used by several other packages. In this lesson only basic level of understanding is required. For introduction into its syntax, consider looking up [pandas cheat sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf) online.
#
# Pandas DataFrame is two-dimensional table with labeled axes; columns are headers, and rows are indexes. It can dynamically changed and can contain heterogeneous data. One row of data is sometimes refered to as an observation.
#
# In this lesson, we will be working with Iris database. It can either downloaded, imported from CSV file or imported from some packages. It includes data about three iris species with 50 samples each. It contains the follow information about the flowers:
#
#  - Its species name
#  - Sepal length cm
#  - Sepal widthin cm
#  - Petal length in cm
#  - Petal width in cm

# %%
import numpy as np
import pandas as pd
import numpy as np
import pandas as pd
from sklearn import datasets
import seaborn
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# Opening CSV file
try:
    dataframe = pd.read_csv("iris.csv")
except IOError:
    pass

# Loading dataset from sklearn package
iris = datasets.load_iris()
# Creating data frame for pandas
dataframe = pd.DataFrame(iris['data'], columns=iris['feature_names'])

# Download from the internet
csv_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
# Requires setting column names manually
col_names = ['Sepal_Length','Sepal_Width','Petal_Length','Petal_Width','Class']
dataframe =  pd.read_csv(csv_url, names = col_names)

setosa=dataframe[dataframe['Class']=='Iris-setosa']
versicolor =dataframe[dataframe['Class']=='Iris-versicolor']
virginica =dataframe[dataframe['Class']=='Iris-virginica']

dataframe.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
dataframe.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width', 'Class'], dtype='object')

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
plt.plot(dataframe["Class"])
plt.xlabel("No. of data points")
plt.show()

# %%
plt.hist(dataframe["Class"],color="black")   
plt.show()

# %%
dataframe.describe()
# Out:
#        Sepal_Length  Sepal_Width  Petal_Length  Petal_Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## Practise
#
# Reproduce following graphs using pyplot package.
#
# Show them on screen. When writing papers, save these plots into separate folder via `plt.savefig()`.
#
# ### Scatter matrix
#
# This is a matrix of scatterplots: each row and column represent a column of a dataframe. On the main diagonal are located the histrograms of the corresponding variable, while other cells contain scatterplots of the corresponding variables.

# %%
fig, ax = plt.subplots(4, 4, sharex = True, sharey = True)

dataframe.plot(y = "Sepal_Length", kind = "hist", ax = ax[0][0])
ax[0][0].get_legend().remove()
ax[0][0].set_ylabel("Sepal_Length")

dataframe.plot(y = "Sepal_Width", kind = "hist", ax = ax[1][1])
ax[1][1].get_legend().remove()

dataframe.plot(y = "Petal_Length", kind = "hist", ax = ax[2][2])
ax[2][2].get_legend().remove()

dataframe.plot(y = "Petal_Width", kind = "hist", ax = ax[3][3])
ax[3][3].get_legend().remove()
ax[3][3].set_xlabel("Petal_Width")

plt.xlim(-2, 9)
plt.ylim(-1, 9)


setosa.plot(x = "Sepal_Width", y = "Sepal_Length", kind = "scatter", ax = ax[0][1], color = 'r')
versicolor.plot(x= "Sepal_Width",y="Sepal_Length",kind="scatter",ax=ax[0][1], color='b')
virginica.plot(x= "Sepal_Width", y="Sepal_Length", kind="scatter", ax=ax[0][1], color='g')

setosa.plot(x = "Sepal_Length", y = "Sepal_Width", kind = "scatter", ax = ax[1][0], color = 'r')
versicolor.plot(x = "Sepal_Length", y = "Sepal_Width", kind = "scatter", ax = ax[1][0], color='b')
virginica.plot(x = "Sepal_Length", y = "Sepal_Width", kind = "scatter", ax = ax[1][0], color='g')

setosa.plot(x = "Petal_Length", y = "Sepal_Length", kind = "scatter", ax = ax[0][2], color = 'r')
versicolor.plot(x = "Petal_Length", y = "Sepal_Length", kind = "scatter", ax = ax[0][2], color='b')
virginica.plot(x = "Petal_Length", y = "Sepal_Length", kind = "scatter", ax = ax[0][2], color='g')

setosa.plot(x = "Petal_Width", y = "Sepal_Length", kind = "scatter", ax = ax[0][3], color = 'r')
versicolor.plot(x = "Petal_Width", y = "Sepal_Length", kind = "scatter", ax = ax[0][3], color='b')
virginica.plot(x = "Petal_Width", y = "Sepal_Length", kind = "scatter", ax = ax[0][3], color='g')

setosa.plot(x = "Petal_Length", y = "Sepal_Width", kind = "scatter", ax = ax[1][2], color = 'r')
versicolor.plot(x = "Petal_Length", y = "Sepal_Width", kind = "scatter", ax = ax[1][2], color='b')
virginica.plot(x = "Petal_Length", y = "Sepal_Width", kind = "scatter", ax = ax[1][2], color='g')

setosa.plot(x = "Petal_Width", y = "Sepal_Width", kind = "scatter", ax = ax[1][3], color = 'r')
versicolor.plot(x = "Petal_Width", y = "Sepal_Width", kind = "scatter", ax = ax[1][3], color='b')
virginica.plot(x = "Petal_Width", y = "Sepal_Width", kind = "scatter", ax = ax[1][3], color='g')

setosa.plot(x = "Sepal_Length", y = "Petal_Length", kind = "scatter", ax = ax[2][0], color = 'r')
versicolor.plot(x = "Sepal_Length", y = "Petal_Length", kind = "scatter", ax = ax[2][0], color='b')
virginica.plot(x = "Sepal_Length", y = "Petal_Length", kind = "scatter", ax = ax[2][0], color='g')

setosa.plot(x = "Sepal_Width", y = "Petal_Length", kind = "scatter", ax = ax[2][1], color = 'r')
versicolor.plot(x= "Sepal_Width", y = "Petal_Length", kind = "scatter", ax = ax[2][1], color='b')
virginica.plot(x= "Sepal_Width", y = "Petal_Length", kind = "scatter", ax = ax[2][1], color='g')

setosa.plot(x = "Petal_Length", y = "Petal_Width", kind = "scatter", ax = ax[2][3], color = 'r')
versicolor.plot(x = "Petal_Length", y = "Petal_Width", kind = "scatter", ax = ax[2][3], color='b')
virginica.plot(x = "Petal_Length", y = "Petal_Width", kind = "scatter", ax = ax[2][3], color='g')

setosa.plot(x = "Sepal_Length", y = "Petal_Width", kind = "scatter", ax = ax[3][0], color = 'r')
versicolor.plot(x = "Sepal_Length", y = "Petal_Width", kind = "scatter", ax = ax[3][0], color='b')
virginica.plot(x = "Sepal_Length", y = "Petal_Width", kind = "scatter", ax = ax[3][0], color='g')

setosa.plot(x = "Sepal_Width", y = "Petal_Width", kind = "scatter", ax = ax[3][1], color = 'r')
versicolor.plot(x= "Sepal_Width", y = "Petal_Width", kind = "scatter", ax = ax[3][1], color='b')
virginica.plot(x= "Sepal_Width", y = "Petal_Width", kind = "scatter", ax = ax[3][1], color='g')

setosa.plot(x = "Petal_Width", y = "Petal_Width", kind = "scatter", ax = ax[3][2], color = 'r')
versicolor.plot(x = "Petal_Width", y = "Petal_Width", kind = "scatter", ax = ax[3][2], color='b')
virginica.plot(x = "Petal_Width", y = "Petal_Width", kind = "scatter", ax = ax[3][2], color='g')


plt.subplots_adjust(wspace=0, hspace=0)

# %%
seaborn.set_style('whitegrid')
seaborn.pairplot(dataframe,hue='Class',height=3, diag_kind = 'hist')
plt.show()

# %% [markdown]
# ### Stacked histograms for each feature

# %%
# Histogram plots here

fig, axes = plt.subplots(2, 2)
colors = ['tab:blue', 'tab:orange', 'tab:green']

for i, ax in enumerate(axes.flat):
    for label, color in zip(range(len(iris.target_names)), colors):
        ax.hist(iris.data[iris.target==label, i], label=             
                iris.target_names[label], color=color, alpha = 0.6)
        ax.set_xlabel(iris.feature_names[i])  
        ax.legend(loc='upper right')
        
plt.show()

# %% [markdown]
# ### Joint plot
#
# Some packages can plot those out of the box. For a paper, if possible, choose a package that can draw all necessary plots.

# %%
# Joint plot here

from matplotlib.gridspec import GridSpec

fig = plt.figure()
gs = GridSpec(4, 4)

ax_scatter = fig.add_subplot(gs[1:4, 0:3])
ax_hist_x = fig.add_subplot(gs[0, 0:3])
ax_hist_y = fig.add_subplot(gs[1:4, 3])

plt.show()

# %%
fig = plt.figure()
gs = GridSpec(4, 4)

ax_scatter = fig.add_subplot(gs[1:4, 0:3])
ax_hist_x = fig.add_subplot(gs[0, 0:3])
ax_hist_y = fig.add_subplot(gs[1:4, 3])

ax_scatter.scatter(dataframe['Sepal_Length'], dataframe['Sepal_Width'])
ax_hist_x.hist(dataframe['Sepal_Length'])
ax_hist_y.hist(dataframe['Sepal_Width'], orientation = 'horizontal')


plt.show()

# %%
setosa = dataframe[dataframe['Class'] == 'Iris-setosa']
virginica = dataframe[dataframe['Class']=='Iris-virginica']
versicolor = dataframe[dataframe['Class']=='Iris-versicolor']
species = dataframe['Class']
colors = {
    'Iris-setosa' : 'tab:blue', 
    'Iris-versicolor' : 'tab:orange',
    'Iris-virginica' : 'tab:green'
    }

# %%
fig = plt.figure()
gs = GridSpec(4, 4)

ax_scatter = fig.add_subplot(gs[1:4, 0:3])
ax_hist_y = fig.add_subplot(gs[0,0:3])
ax_hist_x = fig.add_subplot(gs[1:4, 3])

ax_scatter.scatter(dataframe['Sepal_Length'], dataframe['Sepal_Width'], c=species.map(colors))

ax_hist_y.hist(versicolor['Sepal_Length'], color='tab:orange', alpha=0.6)
ax_hist_y.hist(virginica['Sepal_Length'], color='tab:green', alpha=0.6)
ax_hist_y.hist(setosa['Sepal_Length'], color='tab:blue', alpha=0.6)

ax_hist_x.hist(versicolor['Sepal_Width'], orientation = 'horizontal', color='tab:orange', alpha=0.6)
ax_hist_x.hist(virginica['Sepal_Width'], orientation = 'horizontal', color='tab:green', alpha=0.6)
ax_hist_x.hist(setosa['Sepal_Width'], orientation = 'horizontal', color='tab:blue', alpha=0.6)

plt.show()
